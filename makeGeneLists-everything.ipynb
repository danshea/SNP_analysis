# %%
import pandas as pd

# %%
S11='S11-homozygous-variants.snpeff.ALL.tsv'
R09='R09-homozygous-variants.snpeff.ALL.tsv'

# %%
S11df = pd.read_table(S11, header=None)
R09df = pd.read_table(R09, header=None)

# %%
S11df
# Out:
#            0         1                                                  2  \
# 0        A01      1379                                                  T
# 1        A01      1404                                                  C
# 2        A01      1533                                                  A
# 3        A01      1550                                                  A
# 4        A01      1814                                                  A
# 5        A01      4684                                                  A
# 6        A01      4935                                                  T
# 7        A01      4960                                                  C
# 8        A01      5070                                                  G
# 9        A01      5354                                                  C
# 10       A01      5362                                                  A
# 11       A01      5396                                                  G
# 12       A01      5411                                                  G
# 13       A01      5442                                                  T
# 14       A01      5512                                                  G
# 15       A01      5715                                                  A
# 16       A01      5976                                                  T
# 17       A01      5992                                                  A
# 18       A01      6111                                                  A
# 19       A01      6239                                                  C
# 20       A01      6375                                                  A
# 21       A01      6556                                                  A
# 22       A01      6611                                        ATTCATTCATT
# 23       A01      6793                                                  G
# 24       A01      6994                                                  C
# 25       A01      7109                                                  G
# 26       A01      7149                                                  G
# 27       A01      7210                                                  T
# 28       A01      7225                                                  G
# 29       A01      7263                                                  C
# ...      ...       ...                                                ...
# 1058025  A10  16372770                                                  G
# 1058026  A10  16372892                                                  C
# 1058027  A10  16372923                                                  A
# 1058028  A10  16373065                                                  C
# 1058029  A10  16373088                                                  T
# 1058030  A10  16373621                                                  C
# 1058031  A10  16373629                                                  G
# 1058032  A10  16387242                        CTCTTTTTTTTTTTTTTTATTTTTCGT
# 1058033  A10  16392664                                                 GC
# 1058034  A10  16392777                                                  T
# 1058035  A10  16392780                                                  G
# 1058036  A10  16392890                                                 CT
# 1058037  A10  16394105                                                  G
# 1058038  A10  16394115                                                  G
# 1058039  A10  16394180                                       CAATGTTTTGTT
# 1058040  A10  16394191                                                  T
# 1058041  A10  16394459                                              TTTGT
# 1058042  A10  16394492                                                  A
# 1058043  A10  16394501                                                  T
# 1058044  A10  16394522                                                  G
# 1058045  A10  16394527                                                  A
# 1058046  A10  16394530                                                  T
# 1058047  A10  16396942                                                  T
# 1058048  A10  16396951                                                  C
# 1058049  A10  16396957                                                  T
# 1058050  A10  16396962                                                  T
# 1058051  A10  16397305                                        AAGTTCCAGTC
# 1058052  A10  16405017                                                  C
# 1058053  A10  16405039  ATAGGGTTTAGGGTTTAGGGTTTAGGATTTAGGGTTTAGGGTTTAG...
# 1058054  A10  16405058                                                  G
#
#                                                    3  \
# 0                                                  C
# 1                                                  T
# 2                                                  C
# 3                                                  G
# 4                                                  G
# 5                                                  G
# 6                                                  C
# 7                                                  A
# 8                                                  A
# 9                                                  T
# 10                                                 T
# 11                                                 T
# 12                                                 C
# 13                                                 C
# 14                                                 A
# 15                          ATGGTCAAAAAATAAAAACGAAGG
# 16                                                 C
# 17                                                 G
# 18                                                 G
# 19                                                 T
# 20                                                 C
# 21                                                 C
# 22                              ATTCATTCATTTCATTCATT
# 23                                                 A
# 24                                                 G
# 25                                                 C
# 26                                                 A
# 27                                                 C
# 28                                                 C
# 29                                                 A
# ...                                              ...
# 1058025                                            A
# 1058026                                            T
# 1058027                                            C
# 1058028                                            T
# 1058029                                            G
# 1058030                                            A
# 1058031                                            A
# 1058032                                           CT
# 1058033                                            G
# 1058034                                            C
# 1058035                                            A
# 1058036                                       CTCTTT
# 1058037                                            T
# 1058038                                            T
# 1058039                                            C
# 1058040                                            C
# 1058041                                           TT
# 1058042                                            C
# 1058043                                            G
# 1058044                                            T
# 1058045                                            C
# 1058046                                            C
# 1058047                                            A
# 1058048                                            A
# 1058049                                            G
# 1058050                                            A
# 1058051                                            A
# 1058052                                            T
# 1058053  ATAGGGTTTAGGGTTTAGGATTTAGGGTTTAGGGTTTAGGGTT
# 1058054                                            A
#
#                                                          4
# 0        DP=5;VDB=0.956997;SGB=-0.590765;MQSB=0.833333;...
# 1        DP=3;VDB=0.275636;SGB=-0.511536;MQSB=1;MQ0F=0;...
# 2        DP=10;VDB=0.0510515;SGB=-0.651104;MQSB=0.60053...
# 3        DP=10;VDB=0.112445;SGB=-0.636426;MQSB=0.607698...
# 4        DP=2;VDB=0.9;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2;...
# 5        DP=8;VDB=0.0615984;SGB=-0.590765;MQSB=0.333333...
# 6        DP=3;VDB=0.961028;SGB=-0.511536;MQ0F=0;AF1=1;A...
# 7        DP=2;VDB=0.18;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 8        DP=4;VDB=0.579441;SGB=-0.556411;MQSB=1;MQ0F=0;...
# 9        DP=10;VDB=0.109528;SGB=-0.651104;MQ0F=0;AF1=1;...
# 10       DP=11;VDB=0.139875;SGB=-0.662043;MQSB=1;MQ0F=0...
# 11       DP=12;VDB=0.38486;SGB=-0.556411;MQSB=1;MQ0F=0;...
# 12       DP=12;VDB=0.715037;SGB=-0.676189;MQSB=0.472367...
# 13       DP=12;VDB=0.467235;SGB=-0.670168;MQSB=0.666643...
# 14       DP=21;VDB=0.138089;SGB=-0.692067;MQSB=0.83135;...
# 15       INDEL;IDV=7;IMF=0.7;DP=10;VDB=0.509555;SGB=-0....
# 16       DP=24;VDB=0.52821;SGB=-0.692717;MQSB=0.988053;...
# 17       DP=21;VDB=0.1021;SGB=-0.69168;MQSB=0.959099;MQ...
# 18       DP=15;VDB=0.181278;SGB=-0.686358;MQSB=0.035674...
# 19       DP=13;VDB=0.116802;SGB=-0.680642;MQ0F=0;AF1=1;...
# 20       DP=12;VDB=0.0349067;SGB=-0.676189;MQ0F=0;AF1=1...
# 21       DP=14;VDB=0.346151;SGB=-0.686358;MQSB=0.067205...
# 22       INDEL;IDV=6;IMF=0.461538;DP=13;VDB=0.259674;SG...
# 23       DP=22;VDB=0.283311;SGB=-0.689466;MQSB=0.994135...
# 24       DP=15;VDB=0.630983;SGB=-0.683931;MQSB=0.143152...
# 25       DP=18;VDB=0.550367;SGB=-0.688148;MQSB=0.351229...
# 26       DP=15;VDB=0.181006;SGB=-0.680642;MQSB=1;MQ0F=0...
# 27       DP=16;VDB=0.508575;SGB=-0.688148;MQSB=0.655816...
# 28       DP=14;VDB=0.147066;SGB=-0.686358;MQSB=0.973096...
# 29       DP=13;VDB=0.415179;SGB=-0.680642;MQSB=1;MQ0F=0...
# ...                                                    ...
# 1058025  DP=2;VDB=0.74;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 1058026  DP=5;VDB=0.115146;SGB=-0.556411;MQ0F=0;AF1=1;A...
# 1058027  DP=8;VDB=0.236588;SGB=-0.616816;MQ0F=0;AF1=1;A...
# 1058028  DP=15;VDB=0.000746916;SGB=-0.683931;MQSB=0.236...
# 1058029  DP=21;VDB=0.0343724;SGB=-0.692067;MQSB=0.06506...
# 1058030  DP=24;VDB=0.0904735;SGB=-0.692067;MQSB=0.79154...
# 1058031  DP=21;VDB=0.309556;SGB=-0.69168;MQSB=1;MQ0F=0;...
# 1058032  INDEL;IDV=3;IMF=0.157895;DP=17;VDB=0.348933;SG...
# 1058033  INDEL;IDV=21;IMF=0.954545;DP=22;VDB=0.00277665...
# 1058034  DP=23;VDB=0.0349365;SGB=-0.692352;MQSB=1;MQ0F=...
# 1058035  DP=23;VDB=0.0152831;SGB=-0.683931;MQSB=0.90909...
# 1058036  INDEL;IDV=20;IMF=0.769231;DP=26;VDB=0.444751;S...
# 1058037  DP=15;VDB=0.568269;SGB=-0.688148;MQSB=0.948127...
# 1058038  DP=16;VDB=0.632975;SGB=-0.689466;MQSB=0.878142...
# 1058039  INDEL;IDV=13;IMF=0.866667;DP=15;VDB=0.542796;S...
# 1058040  DP=4;VDB=0.0149992;SGB=-0.556411;MQSB=1;MQ0F=0...
# 1058041  INDEL;IDV=11;IMF=0.733333;DP=15;VDB=0.02;SGB=-...
# 1058042  DP=12;VDB=0.412749;SGB=-0.662043;RPB=1;MQB=1;M...
# 1058043  DP=14;VDB=0.775348;SGB=-0.676189;RPB=1;MQB=1;M...
# 1058044  DP=15;VDB=0.678262;SGB=-0.680642;RPB=1;MQB=1;M...
# 1058045  DP=15;VDB=0.410895;SGB=-0.683931;RPB=1;MQB=1;M...
# 1058046  DP=18;VDB=0.532627;SGB=-0.683931;RPB=1;MQB=1;M...
# 1058047  DP=12;VDB=0.004709;SGB=-0.670168;MQSB=0.428556...
# 1058048  DP=14;VDB=0.00240606;SGB=-0.676189;MQSB=0.0891...
# 1058049  DP=14;VDB=0.00195097;SGB=-0.683931;MQSB=0.1942...
# 1058050  DP=14;VDB=0.00181326;SGB=-0.683931;MQSB=0.2735...
# 1058051  INDEL;IDV=8;IMF=0.888889;DP=9;VDB=0.605799;SGB...
# 1058052  DP=6;VDB=0.155969;SGB=-0.616816;MQ0F=0;AF1=1;A...
# 1058053  INDEL;IDV=1;IMF=0.2;DP=5;VDB=0.267404;SGB=-0.5...
# 1058054  DP=3;VDB=0.06;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
#
# [1058055 rows x 5 columns]

# %%
R09df
# Out:
#            0         1             2                         3  \
# 0        A01      1533             A                         C
# 1        A01      1550             A                         G
# 2        A01      1565             T                         A
# 3        A01      1601             G                         A
# 4        A01      1814             A                         G
# 5        A01      4554             T                         G
# 6        A01      4555             G                         C
# 7        A01      4582             T                         C
# 8        A01      4657             C                         T
# 9        A01      4684             A                         G
# 10       A01      4736             A                         T
# 11       A01      4935             T                         C
# 12       A01      4960             C                         A
# 13       A01      4969             A                         G
# 14       A01      4996             A                         G
# 15       A01      5178           TAA                         T
# 16       A01      5267  GAGAGACAGAGA                    GAGAGA
# 17       A01      5354             C                         T
# 18       A01      5362             A                         T
# 19       A01      5396             G                         T
# 20       A01      5411             G                         C
# 21       A01      5442             T                         C
# 22       A01      5512             G                         A
# 23       A01      5715             A  ATGGTCAAAAAATAAAAACGAAGG
# 24       A01      5976             T                         C
# 25       A01      5992             A                         G
# 26       A01      6111             A                         G
# 27       A01      6239             C                         T
# 28       A01      6375             A                         C
# 29       A01      6556             A                         C
# ...      ...       ...           ...                       ...
# 1047662  A10  16372892             C                         T
# 1047663  A10  16372923             A                         C
# 1047664  A10  16373065             C                         T
# 1047665  A10  16373088             T                         G
# 1047666  A10  16373621             C                         A
# 1047667  A10  16373629             G                         A
# 1047668  A10  16374053             A                         T
# 1047669  A10  16392664            GC                         G
# 1047670  A10  16392777             T                         C
# 1047671  A10  16392780             G                         A
# 1047672  A10  16392890            CT                    CTCTTT
# 1047673  A10  16394105             G                         T
# 1047674  A10  16394115             G                         T
# 1047675  A10  16394180  CAATGTTTTGTT                         C
# 1047676  A10  16394191             T                         C
# 1047677  A10  16394459         TTTGT                        TT
# 1047678  A10  16394492             A                         C
# 1047679  A10  16394501             T                         G
# 1047680  A10  16394522             G                         T
# 1047681  A10  16394527             A                         C
# 1047682  A10  16394530             T                         C
# 1047683  A10  16396942             T                         A
# 1047684  A10  16396951             C                         A
# 1047685  A10  16396957             T                         G
# 1047686  A10  16396962             T                         A
# 1047687  A10  16397305   AAGTTCCAGTC                         A
# 1047688  A10  16404002       TAAAAAA                  TAAAAAAA
# 1047689  A10  16405017             C                         T
# 1047690  A10  16405058             G                         A
# 1047691  A10  16405065             A                         G
#
#                                                          4
# 0        DP=9;VDB=0.251321;SGB=-0.590765;MQSB=1;MQ0F=0;...
# 1        DP=6;VDB=0.036809;SGB=-0.616816;MQSB=0.5;MQ0F=...
# 2        DP=6;VDB=0.0643982;SGB=-0.590765;MQSB=1;MQ0F=0...
# 3        DP=2;VDB=0.02;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 4        DP=3;VDB=0.38;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 5        DP=3;VDB=0.6;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2;...
# 6        DP=3;VDB=0.64;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 7        DP=2;VDB=0.38;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 8        DP=7;VDB=0.291224;SGB=-0.636426;MQ0F=0;AF1=1;A...
# 9        DP=11;VDB=0.251186;SGB=-0.670168;MQSB=0.75;MQ0...
# 10       DP=16;VDB=0.0288079;SGB=-0.683931;MQSB=1;MQ0F=...
# 11       DP=7;VDB=0.23129;SGB=-0.616816;MQ0F=0;AF1=1;AC...
# 12       DP=6;VDB=0.215799;SGB=-0.616816;MQ0F=0;AF1=1;A...
# 13       DP=6;VDB=0.186688;SGB=-0.616816;MQ0F=0;AF1=1;A...
# 14       DP=5;VDB=0.431509;SGB=-0.590765;MQ0F=0;AF1=1;A...
# 15       INDEL;IDV=3;IMF=1;DP=3;VDB=0.1;SGB=-0.453602;M...
# 16       INDEL;IDV=6;IMF=0.75;DP=8;VDB=0.299032;SGB=-0....
# 17       DP=9;VDB=0.4587;SGB=-0.616816;MQ0F=0;AF1=1;AC1...
# 18       DP=9;VDB=0.170074;SGB=-0.636426;MQSB=1;MQ0F=0;...
# 19       DP=10;VDB=0.765925;SGB=-0.556411;MQSB=1;MQ0F=0...
# 20       DP=13;VDB=0.792905;SGB=-0.680642;MQSB=1;MQ0F=0...
# 21       DP=12;VDB=0.538108;SGB=-0.680642;MQSB=0.6821;M...
# 22       DP=11;VDB=0.178328;SGB=-0.670168;MQSB=0.824834...
# 23       INDEL;IDV=9;IMF=0.6;DP=15;VDB=0.399491;SGB=-0....
# 24       DP=30;VDB=0.717558;SGB=-0.693021;MQSB=0.878264...
# 25       DP=33;VDB=0.337298;SGB=-0.69311;MQSB=0.990396;...
# 26       DP=26;VDB=0.563318;SGB=-0.692914;MQSB=0.078260...
# 27       DP=19;VDB=0.30914;SGB=-0.689466;MQSB=1;MQ0F=0;...
# 28       DP=10;VDB=0.0718443;SGB=-0.662043;MQSB=1;MQ0F=...
# 29       DP=14;VDB=0.625556;SGB=-0.683931;MQSB=0.864302...
# ...                                                    ...
# 1047662  DP=5;VDB=0.705481;SGB=-0.590765;MQ0F=0;AF1=1;A...
# 1047663  DP=6;VDB=0.284843;SGB=-0.590765;MQ0F=0;AF1=1;A...
# 1047664  DP=14;VDB=0.746499;SGB=-0.686358;MQSB=0.833333...
# 1047665  DP=15;VDB=0.701275;SGB=-0.676189;MQSB=1;MQ0F=0...
# 1047666  DP=21;VDB=0.0761188;SGB=-0.691153;MQSB=1;MQ0F=...
# 1047667  DP=24;VDB=0.0922615;SGB=-0.692067;MQSB=1;MQ0F=...
# 1047668  DP=16;VDB=0.0529733;SGB=-0.676189;MQSB=0.92444...
# 1047669  INDEL;IDV=19;IMF=0.95;DP=20;VDB=0.773964;SGB=-...
# 1047670  DP=19;VDB=0.135926;SGB=-0.691153;MQSB=0.817948...
# 1047671  DP=19;VDB=0.293996;SGB=-0.686358;MQSB=0.927743...
# 1047672  INDEL;IDV=17;IMF=0.809524;DP=21;VDB=0.530407;S...
# 1047673  DP=22;VDB=0.0286515;SGB=-0.690438;MQSB=0.35286...
# 1047674  DP=21;VDB=0.031809;SGB=-0.690438;MQSB=0.352866...
# 1047675  INDEL;IDV=16;IMF=0.8;DP=20;VDB=0.442372;SGB=-0...
# 1047676  DP=1;SGB=-0.379885;MQ0F=0;AF1=1;AC1=2;DP4=0,0,...
# 1047677  INDEL;IDV=8;IMF=0.727273;DP=11;SGB=-0.379885;M...
# 1047678  DP=9;VDB=0.35322;SGB=-0.636426;MQSB=0.5;MQ0F=0...
# 1047679  DP=11;VDB=0.353119;SGB=-0.662043;MQSB=0.642857...
# 1047680  DP=11;VDB=0.444909;SGB=-0.636426;MQSB=0.7;MQ0F...
# 1047681  DP=12;VDB=0.617745;SGB=-0.676189;MQSB=0.643095...
# 1047682  DP=12;VDB=0.617745;SGB=-0.676189;MQSB=0.643095...
# 1047683  DP=18;VDB=0.572753;SGB=-0.686358;MQSB=0.913931...
# 1047684  DP=17;VDB=0.389077;SGB=-0.676189;MQSB=0.774755...
# 1047685  DP=17;VDB=0.0591826;SGB=-0.680642;MQ0F=0;AF1=1...
# 1047686  DP=16;VDB=0.272882;SGB=-0.683931;MQSB=0.314383...
# 1047687  INDEL;IDV=16;IMF=1;DP=16;VDB=0.00522732;SGB=-0...
# 1047688  INDEL;IDV=10;IMF=0.47619;DP=21;VDB=0.0684329;S...
# 1047689  DP=8;VDB=0.0283055;SGB=-0.636426;MQ0F=0;AF1=1;...
# 1047690  DP=2;VDB=0.02;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 1047691  DP=2;VDB=0.02;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
#
# [1047692 rows x 5 columns]

# %%
def writeGeneLists(df, filename):
    isINDEL = False
    with open(filename, 'w') as fh:
        for (index, row) in df.iterrows():
            chromosome = row[0]
            position   = row[1]
            reference  = row[2]
            alternative= row[3]
            info       = row[4]
            # Parse the info entry
            # First split it on ';'
            info_list = info.split(';')
            if info[0] == 'INDEL':
                isINDEL = True
            else:
                isINDEL = False
            for i in info_list:
                if i.startswith('ANN='):
                    ANN = i
                    break
            # Next parse the ANN
            ANN_list = ANN.split('|')
            effects = ANN_list[1]
            impact  = ANN_list[2]
            gene    = ANN_list[3]
            
            # Write out the details as tab-delimited format
            outline = '\t'.join([chromosome, str(position), reference, alternative, 
                                 'INDEL' if isINDEL else 'SNP', effects.replace('&',','), impact, gene])
            fh.write('{}\n'.format(outline))

# %%
writeGeneLists(S11df, 'S11-homozygous-variants.snpeff.ALL.parsed.tsv')

# %%
writeGeneLists(R09df, 'R09-homozygous-variants.snpeff.ALL.parsed.tsv')
