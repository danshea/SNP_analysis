# %%
import pandas as pd

# %%
S11='S11-homozygous-variants.snpeff.unique.missense.tsv'
R09='R09-homozygous-variants.snpeff.unique.missense.tsv'

# %%
S11df = pd.read_table(S11, header=None)
R09df = pd.read_table(R09, header=None)

# %%
S11df
# Out:
#          0         1  2  3                                                  4
# 0      A01    104713  A  G  DP=19;VDB=0.111138;SGB=-0.688148;MQSB=1;MQ0F=0...
# 1      A01    108767  C  T  DP=17;VDB=0.0288131;SGB=-0.680642;MQSB=0.94394...
# 2      A01    115337  A  T  DP=14;VDB=0.505181;SGB=-0.683931;MQSB=0.765017...
# 3      A01    115368  A  G  DP=18;VDB=0.716612;SGB=-0.690438;MQSB=0.687289...
# 4      A01    115488  G  A  DP=22;VDB=0.18285;SGB=-0.692352;MQSB=0.382806;...
# 5      A01    115691  A  G  DP=14;VDB=0.585809;SGB=-0.683931;MQSB=0.899815...
# 6      A01    119339  A  G  DP=10;VDB=0.0735697;SGB=-0.670168;MQSB=0.33332...
# 7      A01    120770  T  G  DP=12;VDB=0.902154;SGB=-0.670168;MQSB=0.857112...
# 8      A01    121606  T  G  DP=9;VDB=0.666297;SGB=-0.662043;MQSB=0.89338;M...
# 9      A01    121638  T  A  DP=13;VDB=0.945331;SGB=-0.670168;MQSB=0.895781...
# 10     A01    121685  G  A  DP=10;VDB=0.0743943;SGB=-0.651104;MQSB=0.33333...
# 11     A01    126647  A  C  DP=19;VDB=0.510804;SGB=-0.690438;MQSB=0.968927...
# 12     A01    127814  G  C  DP=14;VDB=0.613071;SGB=-0.686358;MQSB=0.945959...
# 13     A01    220307  T  G  DP=17;VDB=0.748707;SGB=-0.689466;MQSB=1;MQ0F=0...
# 14     A01    220309  T  G  DP=17;VDB=0.693781;SGB=-0.690438;MQSB=1;MQ0F=0...
# 15     A01    271314  G  A  DP=14;VDB=0.0325454;SGB=-0.680642;MQSB=0.83800...
# 16     A01    271421  C  T  DP=10;VDB=0.49524;SGB=-0.651104;MQSB=0.333333;...
# 17     A01    271429  A  T  DP=10;VDB=0.324419;SGB=-0.590765;MQSB=1;MQ0F=0...
# 18     A01    271516  T  C  DP=24;VDB=0.0528464;SGB=-0.692067;MQSB=0.02914...
# 19     A01    271556  T  G  DP=23;VDB=0.270237;SGB=-0.692352;MQSB=0.007374...
# 20     A01    274835  G  A  DP=11;VDB=0.228818;SGB=-0.676189;MQSB=1;MQ0F=0...
# 21     A01    274845  C  A  DP=11;VDB=0.231253;SGB=-0.676189;MQSB=1;MQ0F=0...
# 22     A01    280146  G  A  DP=12;VDB=0.139876;SGB=-0.662043;MQSB=0.89338;...
# 23     A01    282473  C  T  DP=21;VDB=0.570312;SGB=-0.691153;MQSB=1;MQ0F=0...
# 24     A01    292935  G  A  DP=18;VDB=0.214264;SGB=-0.686358;MQSB=1;MQ0F=0...
# 25     A01    293133  A  C  DP=16;VDB=0.37956;SGB=-0.686358;MQSB=1;MQ0F=0;...
# 26     A01    294767  C  A  DP=23;VDB=0.439008;SGB=-0.690438;MQSB=0.981133...
# 27     A01    295381  G  A  DP=22;VDB=0.154455;SGB=-0.69168;MQSB=0.920044;...
# 28     A01    316503  A  G  DP=25;VDB=0.303136;SGB=-0.691153;MQSB=0.447612...
# 29     A01    316504  C  T  DP=25;VDB=0.337124;SGB=-0.690438;MQSB=0.393241...
# ...    ...       ... .. ..                                                ...
# 37869  A10  15760308  C  G  DP=5;VDB=0.908601;SGB=-0.590765;MQ0F=0;AF1=1;A...
# 37870  A10  15760309  T  C  DP=5;VDB=0.900941;SGB=-0.590765;MQ0F=0;AF1=1;A...
# 37871  A10  15760335  G  A  DP=4;VDB=0.535497;SGB=-0.556411;MQ0F=0;AF1=1;A...
# 37872  A10  15760370  C  G  DP=4;VDB=0.72;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 37873  A10  15761291  T  C  DP=2;VDB=0.92;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 37874  A10  15761311  C  T  DP=2;VDB=0.92;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 37875  A10  15761418  T  G  DP=2;VDB=0.36;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 37876  A10  15761419  T  C  DP=2;VDB=0.36;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 37877  A10  15761422  A  G  DP=2;VDB=0.36;SGB=-0.453602;MQ0F=0;AF1=1;AC1=2...
# 37878  A10  15761455  G  T  DP=4;VDB=0.267404;SGB=-0.511536;MQ0F=0;AF1=1;A...
# 37879  A10  15761459  A  G  DP=4;VDB=0.459448;SGB=-0.556411;MQ0F=0;AF1=1;A...
# 37880  A10  15761539  C  T  DP=3;VDB=0.382879;SGB=-0.511536;MQ0F=0;AF1=1;A...
# 37881  A10  15761610  C  T  DP=2;VDB=0.26;SGB=-0.453602;MQSB=1;MQ0F=0;AF1=...
# 37882  A10  15766087  C  T  DP=15;VDB=0.191846;SGB=-0.680642;MQSB=0.982603...
# 37883  A10  15821749  T  A  DP=11;VDB=0.72462;SGB=-0.651104;MQSB=0.868321;...
# 37884  A10  15821907  G  T  DP=7;VDB=0.622148;SGB=-0.616816;MQSB=0.861511;...
# 37885  A10  15821925  T  G  DP=7;VDB=0.753018;SGB=-0.636426;MQSB=0.810265;...
# 37886  A10  15822390  A  T  DP=11;VDB=0.470665;SGB=-0.636426;MQSB=0.405132...
# 37887  A10  15921812  A  G  DP=13;VDB=0.0988809;SGB=-0.676189;MQSB=0.18498...
# 37888  A10  15921839  T  G  DP=15;VDB=0.229729;SGB=-0.686358;MQSB=0.945959...
# 37889  A10  15921936  C  T  DP=12;VDB=0.63445;SGB=-0.676189;MQSB=0.742931;...
# 37890  A10  15921956  G  A  DP=11;VDB=0.851111;SGB=-0.676189;MQSB=0.891517...
# 37891  A10  15929424  G  A  DP=16;VDB=0.105604;SGB=-0.689466;MQSB=0.948436...
# 37892  A10  15930473  G  T  DP=16;VDB=0.0304787;SGB=-0.670168;MQSB=0.85711...
# 37893  A10  15930662  T  A  DP=18;VDB=0.731986;SGB=-0.670168;MQSB=0.857112...
# 37894  A10  15941071  C  T  DP=15;VDB=0.0125399;SGB=-0.683931;MQSB=0.34251...
# 37895  A10  16023269  A  G  DP=29;VDB=0.0484542;SGB=-0.692562;MQSB=0.89539...
# 37896  A10  16024861  C  G  DP=12;VDB=0.969087;SGB=-0.680642;MQSB=0.864013...
# 37897  A10  16127610  G  A  DP=11;VDB=0.751441;SGB=-0.662043;RPB=1;MQB=1;M...
# 37898  A10  16293781  G  A  DP=22;VDB=0.10705;SGB=-0.69168;MQSB=0.965977;M...
#
# [37899 rows x 5 columns]

# %%
R09df
# Out:
#          0         1  2    3  \
# 0      A01     77147  T    G
# 1      A01    121734  G    T
# 2      A01    127991  C    T
# 3      A01    128056  A    T
# 4      A01    128119  C    T
# 5      A01    129058  A    T
# 6      A01    129203  T    C
# 7      A01    129205  G    A
# 8      A01    130391  T    G
# 9      A01    130745  G    A
# 10     A01    130806  A    G
# 11     A01    132166  T    C
# 12     A01    132215  A    C
# 13     A01    132332  A    G
# 14     A01    132447  C    A
# 15     A01    132463  G    C
# 16     A01    132723  T    C
# 17     A01    133101  G    T
# 18     A01    133156  C    A
# 19     A01    138543  C    A
# 20     A01    142995  G    T
# 21     A01    143010  A    T
# 22     A01    143055  T    G
# 23     A01    143069  G    C
# 24     A01    145044  A    C
# 25     A01    145049  C    T
# 26     A01    145142  G    A
# 27     A01    145168  G    T
# 28     A01    145179  G    A
# 29     A01    145196  T    A
# ...    ...       ... ..  ...
# 38584  A10  16086550  G    T
# 38585  A10  16086828  C    T
# 38586  A10  16086835  G    T
# 38587  A10  16086836  G    A
# 38588  A10  16086839  C    T
# 38589  A10  16099911  C    A
# 38590  A10  16100078  C    A
# 38591  A10  16127101  C    T
# 38592  A10  16205633  G    T
# 38593  A10  16210177  G    C
# 38594  A10  16216228  C    T
# 38595  A10  16217237  C    G
# 38596  A10  16218067  G    C
# 38597  A10  16218086  C    T
# 38598  A10  16218096  C    T
# 38599  A10  16218142  A  G,C
# 38600  A10  16218516  T    A
# 38601  A10  16218556  C    A
# 38602  A10  16218726  T    C
# 38603  A10  16220110  C    T
# 38604  A10  16222784  A    G
# 38605  A10  16231905  C    T
# 38606  A10  16232955  G    A
# 38607  A10  16233006  G    A
# 38608  A10  16235994  G    A
# 38609  A10  16239235  A    C
# 38610  A10  16239277  A    T
# 38611  A10  16240097  C    G
# 38612  A10  16240160  C    T
# 38613  A10  16240378  A    G
#
#                                                        4
# 0      DP=10;VDB=0.187011;SGB=-0.651104;MQSB=0.900802...
# 1      DP=14;VDB=0.32322;SGB=-0.670168;MQSB=1.00775;M...
# 2      DP=20;VDB=0.246268;SGB=-0.689466;MQSB=0.729697...
# 3      DP=23;VDB=0.822284;SGB=-0.692352;RPB=1;MQB=1;M...
# 4      DP=19;VDB=0.0115527;SGB=-0.686358;MQSB=0.74081...
# 5      DP=20;VDB=0.307628;SGB=-0.690438;MQSB=0.22313;...
# 6      DP=20;VDB=0.361542;SGB=-0.691153;MQSB=0.46131;...
# 7      DP=20;VDB=0.523598;SGB=-0.690438;MQSB=0.562035...
# 8      DP=15;VDB=0.056073;SGB=-0.686358;MQSB=0.375311...
# 9      DP=21;VDB=0.538067;SGB=-0.69168;MQSB=0.118756;...
# 10     DP=27;VDB=0.0869122;SGB=-0.692717;MQSB=0.19843...
# 11     DP=18;VDB=0.0160709;SGB=-0.689466;MQSB=0.86324...
# 12     DP=19;VDB=0.354882;SGB=-0.690438;MQSB=0.687289...
# 13     DP=19;VDB=0.0952892;SGB=-0.688148;MQSB=0.56978...
# 14     DP=11;VDB=0.784517;SGB=-0.651104;MQSB=0.5;MQ0F...
# 15     DP=14;VDB=0.653136;SGB=-0.670168;MQSB=0.095234...
# 16     DP=8;VDB=0.457239;SGB=-0.651104;MQSB=1;MQ0F=0;...
# 17     DP=8;VDB=0.00599576;SGB=-0.636426;MQSB=1.01283...
# 18     DP=13;VDB=0.178328;SGB=-0.670168;MQSB=0.895781...
# 19     DP=31;VDB=0.00993644;SGB=-0.693097;MQSB=0.8789...
# 20     DP=5;VDB=0.775568;SGB=-0.556411;MQSB=1;MQ0F=0;...
# 21     DP=5;VDB=0.820274;SGB=-0.556411;MQSB=1;MQ0F=0;...
# 22     DP=9;VDB=0.0883928;SGB=-0.636426;MQSB=1.01283;...
# 23     DP=10;VDB=0.163983;SGB=-0.662043;MQSB=0.924584...
# 24     DP=18;VDB=0.069214;SGB=-0.690438;MQSB=0.99881;...
# 25     DP=18;VDB=0.0462012;SGB=-0.689466;MQSB=0.98747...
# 26     DP=11;VDB=0.999872;SGB=-0.616816;MQSB=1;MQ0F=0...
# 27     DP=11;VDB=0.637028;SGB=-0.670168;MQSB=1;MQ0F=0...
# 28     DP=12;VDB=0.441513;SGB=-0.670168;MQ0F=0;AF1=1;...
# 29     DP=12;VDB=0.587338;SGB=-0.670168;MQ0F=0;AF1=1;...
# ...                                                  ...
# 38584  DP=29;VDB=0.665447;SGB=-0.692976;MQSB=0.095634...
# 38585  DP=13;VDB=0.108895;SGB=-0.662043;MQSB=1;MQ0F=0...
# 38586  DP=13;VDB=0.0412078;SGB=-0.680642;MQSB=1;MQ0F=...
# 38587  DP=13;VDB=0.0617175;SGB=-0.676189;MQSB=1;MQ0F=...
# 38588  DP=13;VDB=0.0646505;SGB=-0.683931;MQSB=1;MQ0F=...
# 38589  DP=14;VDB=0.391706;SGB=-0.680642;MQSB=0.94394;...
# 38590  DP=21;VDB=0.236092;SGB=-0.683931;MQSB=0.030675...
# 38591  DP=3;VDB=0.921489;SGB=-0.511536;MQSB=1;MQ0F=0;...
# 38592  DP=14;VDB=0.445356;SGB=-0.676189;MQSB=1;MQ0F=0...
# 38593  DP=24;VDB=0.334399;SGB=-0.692067;MQSB=0.943233...
# 38594  DP=23;VDB=0.315921;SGB=-0.692067;MQSB=0.16468;...
# 38595  DP=14;VDB=0.399491;SGB=-0.680642;MQSB=0.594978...
# 38596  DP=11;VDB=0.0014134;SGB=-0.670168;MQSB=1.00775...
# 38597  DP=13;VDB=0.0491895;SGB=-0.676189;MQSB=0.96464...
# 38598  DP=13;VDB=0.131274;SGB=-0.680642;MQSB=0.95494;...
# 38599  DP=11;VDB=0.0211987;SGB=-0.676189;MQSB=0.95095...
# 38600  DP=11;VDB=0.0267105;SGB=-0.662043;MQSB=0.85714...
# 38601  DP=19;VDB=0.280002;SGB=-0.690438;MQSB=0.960728...
# 38602  DP=8;VDB=0.648709;SGB=-0.651104;MQSB=0.900802;...
# 38603  DP=19;VDB=0.462928;SGB=-0.691153;MQSB=0.373326...
# 38604  DP=19;VDB=0.637231;SGB=-0.689466;MQSB=1;MQ0F=0...
# 38605  DP=20;VDB=0.729744;SGB=-0.691153;MQSB=0.793985...
# 38606  DP=24;VDB=0.174914;SGB=-0.692562;MQSB=0.936864...
# 38607  DP=23;VDB=0.183457;SGB=-0.692067;MQSB=0.916401...
# 38608  DP=20;VDB=0.454874;SGB=-0.690438;MQSB=0.85832;...
# 38609  DP=15;VDB=0.412929;SGB=-0.686358;MQSB=1;MQ0F=0...
# 38610  DP=13;VDB=0.187503;SGB=-0.670168;MQSB=1;MQ0F=0...
# 38611  DP=25;VDB=0.460347;SGB=-0.692067;MQSB=0.807118...
# 38612  DP=20;VDB=0.402928;SGB=-0.690438;MQSB=0.605689...
# 38613  DP=14;VDB=0.541492;SGB=-0.686358;MQSB=0.428703...
#
# [38614 rows x 5 columns]

# %%
def writeGeneLists(df, filename):
    isINDEL = False
    with open(filename, 'w') as fh:
        for (index, row) in df.iterrows():
            chromosome = row[0]
            position   = row[1]
            reference  = row[2]
            alternative= row[3]
            info       = row[4]
            # Parse the info entry
            # First split it on ';'
            info_list = info.split(';')
            if info[0] == 'INDEL':
                isINDEL = True
            else:
                isINDEL = False
            for i in info_list:
                if i.startswith('ANN='):
                    ANN = i
                    break
            # Next parse the ANN
            ANN_list = ANN.split('|')
            effects = ANN_list[1]
            impact  = ANN_list[2]
            gene    = ANN_list[3]
            
            # Write out the details as tab-delimited format
            outline = '\t'.join([chromosome, str(position), reference, alternative, 
                                 'INDEL' if isINDEL else 'SNP', effects.replace('&',','), impact, gene])
            fh.write('{}\n'.format(outline))

# %%
writeGeneLists(S11df, 'S11-homozygous-variants.snpeff.unique.missense.parsed.tsv')

# %%
writeGeneLists(R09df, 'R09-homozygous-variants.snpeff.unique.missense.parsed.tsv')
